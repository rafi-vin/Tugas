# %% [markdown]
# ![IMG-20241009-WA0061.jpg](data:image/jpeg;base64,...)![IMG-20241009-WA0060.jpg](data:image/jpeg;base64,...)![IMG-20241009-WA0059.jpg](data:image/jpeg;base64,...)![IMG-20241009-WA0058.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Tugas pertemuan python pertama 07-10-2024
